# %% [markdown]
# ## NUMPY
#   - SHORT OF NUMERICICAL PYTHON
#   - FOUNDATIONAL PACKAGE FOR NUMERICAL COMPUTING IN PYTHON
#   - PROVIDES NDARRAYS OBJECT WHICH IS AN EFFICIENT MULTIDIMENSTUINAL ARRAYS PROVIDNG FAST ARRAY ORIENTED OPERATIONS
#   - PROVIDES A LOT OF FUNCTIONS.

# %% [markdown]
# # 1. What is NumPy?
#
# Answer:
#
# NumPy (Numerical Python) is a Python library used for numerical computing. It provides a powerful N-dimensional array object and mathematical functions  on large datasets.
#
#
#
# # 2. Why is NumPy faster than Python lists?
#
# Answer:
#
# NumPy is faster because:
#
# It stores elements in contiguous memory.
# All elements have the same data type.
# It performs operations using optimized C code.
# It supports vectorized operations, avoiding Python loops.
#
# # 3 Difference between Python List and NumPy Array
# Python List	                      NumPy Array
# Can store different data types	 Stores same data type
# Slower	                         Faster
# More memory usage	               Less memory usage
# Doesn't support vectorized operations	Supports vectorized operations
#
#
# # 4  What is Vectorization?
#
# Answer:
#
# Vectorization means performing operations on an entire array without writing loops.
#
# # 5 What are shape, size, and ndim?
#
#  # shape
#
# Returns rows and columns.
#
#
# # size
#
# Total number of elements.
#
# # ndim
#
# Number of dimensions.
#
# # 6. Difference between reshape() and resize()
#  # reshape()
#
# Returns a new array with a different shape.
#
# Original array remains unchanged.
#
#
# # resize()
#
# Changes the original array itself.
#
# # 7. Explain axis=0 and axis=1
#
#  # axis=0
#
# Works column-wise.
#
# # axis=1
#
# Works row-wise.
#
# # 8. Difference between concatenate(), hstack(), and vstack()
#
# # concatenate
# np.concatenate((a,b), axis=0)
#
# Flexible because you choose the axis.
#
# # hstack
#
# Joins horizontally.
#
# # vstack
#
# Joins vertically.
#
#
#  # 9 What is Boolean Indexing?
#
# Selecting elements based on a condition.
#
# a = np.array([10,20,30,40])
#
# a[a>20]
#
#
# # 10. What is Broadcasting?
#
# Broadcasting allows NumPy to perform arithmetic on arrays of different but compatible shapes.
#
# Example
#
# a = np.array([1,2,3])
#
# a + 10
#
#
# # 11 What is Fancy Indexing?
#
# Access elements using lists or arrays of indices.
#
#
# # 12 Why is NumPy important for Pandas and Machine Learning?
#
# "NumPy is the backbone of data science because Pandas, Scikit-learn, SciPy, and many other libraries rely on NumPy arrays for fast and efficient numerical computation.

# %%
import numpy as np

# %% [markdown]
# ## CREATING ND ARRAYS
#   - CREATING NDARRAYS FROM AN OBJECT

# %%
l1 = [1,2,3,4,5]       # list 
a1 = numpy.array(l1)
a1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 l1 = [1,2,3,4,5]       # list
# ----> 2 a1 = numpy.array(l1)
#       3 a1
#
# NameError: name 'numpy' is not defined

# %%
l1 = [1,2,3,4,5]
a1 = np.array(l1)
a1

# %%
type(a1)

# %%
t1 = (1,2,3,4,5)    # tuple
a1 = np.array(t1)
a1
# Out:
# array([1, 2, 3, 4, 5])

# %%
a1 = np.array(range(2,11,2))
a1
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
a1.ndim    # to check the dimentions    it has single [ bracket so it is one dimesion
# Out:
# 1

# %%
a1.shape       #  (5,)   why , this interview Q
# Out:
# (5,)

# %%
a1 = np.array([[1,2,3],[4,5,6]])
a1.shape

# %%
a1.ndim

# %%
ab = np.arange(9)
ab
ab.dtype          # it check the type

# %%
a1 = np.array([[[1,2,3],[4,5,6]]])
a1.shape
a1

# %%
a1.ndim

# %%
a1.shape

# %%
a1 = np.array([[[[1,2,3],[4,5,6]]]])
a1.shape

# %%
a1 = np.array([[[[[1,2,3],[4,5,6]]]]])
a1.shape

# %%
a1 = np.array([[[1,2],[3,4]],[[5,6],[7,8]]])
a1.shape

# %%
a1.ndim

# %%
a1 = np.array([[[1.1,2],[3,4]],[[5,6.6],[7.25,8]]]) 
a1.dtype

# %%
a1 = np.array([[[1.1,2],[3,4]],[[5,6.6],[7.25,8]]]) 
a1.shape

# %% [markdown]
# #  change the data type

# %%
a1 = np.array([[[1.1,2],[3,4]],[[5,6.6],[7.25,8]]]) 
b1 = a1.astype(int)    ## it can change the type ....
b1

# %% [markdown]
# ## CREATING NDARRAYS OF ONES ,ZEROES AND SPECIFIC VALUES

# %%
np.ones((5,5))

# %%
np.ones((5,5) ,dtype=int)

# %%
np.ones((3,2,4) ,dtype=int)

# %%
a= np.zeros((4,2,5))
a

# %%
np.full((4,5),fill_value=2 ,dtype=int)

# %%
np.eye(5)           # identity matrix.

# %%
b= np.full((4,5) ,fill_value=5)
np.fill_diagonal(b,4)
b

# %% [markdown]
# # OPERATIONS ON NDARRAYS

# %%
l = [1,2,3,4,5]
l + 2

# %%
a = np.array([1,2,3,4,5])
a

# %%
a + 2      # this is main use of numpy

# %%
b = np.array([4,5,6,7,8])

# %%
a + b

# %%
a

# %%
a - b

# %%
a * b

# %%
a / b

# %%
b / a

# %%
a % 2

# %%
a > b

# %%
a

# %%
b

# %%
a ** b

# %%
a // b

# %% [markdown]
# ## INDEXING AND SLICING IN SINGLE DIMENSION ARRAY

# %%
a = np.arange(10)
a

# %%
a

# %%
a[-1]

# %%
a[-3:-7:3]

# %% [markdown]
#  ## RESHAPE  AND TRANSPOSE

# %%
a = np.arange(16)

# %%
a

# %%
a.shape

# %%
a.ndim

# %%
a = a.reshape((4,4))
a

# %%
a = a.reshape((8,2))
a

# %%
a = a.reshape((2,8))
a

# %%
a = a.reshape((2,2,2,2))
a

# %%
a = np.arange(16).reshape((4,4))
a

# %%
a.T

# %% [markdown]
#  # ONE DIMENSION ARRAY

# %% [markdown]
# # FUNCTIONS

# %%
a = np.array([2,3,6,8,9,4,5,1,7])
a

# %%
a.sort()
a

# %%
np.sqrt(a)

# %%
np.cbrt(a)

# %%
np.abs([-1,-2,4,-5,6,-8])

# %%
np.add([1,2,3],[4,5,6])

# %%
np.subtract([1,2,3],[4,5,6])

# %%
np.multiply([1,2,3],[4,5,6])

# %%
np.divide([1,2,3],[4,5,6])

# %%
np.minimum(a1,a2)

# %%
a1 = np.array([2,1,3,6,3,4])
a2 = np.array([3,4,2,5,8,5])

# %%
np.sum(a1)   # sum tak one argument only

# %%
# if we want to add
a1 + a2

# %%
np.var(a1)

# %%
np.std(a1)

# %%
 np.minimum(a1,a2)

# %%
np.maximum(a1,a2)

# %%
np.greater(a1,a2)

# %%
np.greater(a2,a1)

# %%
np.less(a1,a2)

# %%
np.less(a2,a1)

# %%
a1 = np.arange(21)
a1

# %%
a1.mean()

# %%
np.median(a1)

# %%
a1.min()

# %%
a1.max()

# %%
a1.sum()

# %% [markdown]
# ## TWO DIMENSION ARRAY

# %%
a = np.arange(64).reshape(8,8)
a

# %%
a.shape

# %% [markdown]
# a.min()

# %%
a.mean()

# %%
a.mean(axis=0)    #  axis=0 column-wise (top to bottom).

# %%
a.mean(axis=1)   # Result for each row

# %%
a.max()

# %%
a.max(axis=1)

# %%
a.max(axis=0)

# %%
a.min(axis=1)

# %%
a.min(axis=0)

# %%
x = np.array([1,2,4,3,3,4])
x

# %%
np.argmax(x)     # returns the index (position) of the largest element in an array.

# %%
np.argmin(x)

# %%
a = np.arange(9).reshape((3,3))
a

# %%
np.argmax(a)

# %%
np.argmin(a)

# %%
np.argmax(a,axis = 0)

# %%
np.argmax(a,axis = 1)

# %%
np.argmin(a,axis = 0)

# %%
np.argmin(a,axis = 1)

# %%
a = np.arange(16).reshape(4,4)
a

# %%
a =np.array([2,1,5,4,3,5,6,7,3,9,2,3]).reshape(3,4)
a

# %%
b = np.insert(a,1,[5,1,6,7],axis=0)
b

# %%
c = np.insert(a,1,[5,1,6,7],axis=1) 
c

# %%
a = np.array([10,20,30])
b = np.append(a,[40,50])
b

# %%
b=np.delete(a,1)
b

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])
np.vstack((a,b))   # vertically stack

# %%
np.hstack((a,b))    # horizonatally

# %%
# spliting

a = np.array([10,20,30,40,50,60])
np.split(a,3)

# %%
np.split(a,2)

# %%
np.argmax(a)

# %%
np.argmax(a,axis=0)

# %%
np.argmax(a,axis=1)

# %%
a1 = a.reshape(1,3,4)
a1

# %%
a2 = a1.squeeze()     # squeeze() removes dimensions of size 1 from an array  but first size should be 1
a2

# %%
a1 = np.arange(5)
a2 = np.arange(5,10)
print(a1)
print(a2)

# %%
a1

# %%
np.concatenate((a1,a2))

# %%
a = np.arange(5)
b = np.arange(5,10)

# %%
a

# %%
b

# %%
np.concatenate((a,b))

# %%
np.concatenate((a,b ),axis=1)

# %%
np.concatenate((a2,a1))

# %%
a1 = a1.reshape(1,5)
a1

# %%
a2 = a2.reshape(1,5)
a2

# %%
np.concatenate((a2,a1),axis=0)

# %%
np.concatenate((a2,a1),axis=1)

# %% [markdown]
# ## RANDOM NUMBERS

# %%
np.random.randint(1,100)

# %%
np.random.randint(1,100,10)

# %%
np.random.randint(1,100,(10,10))

# %%
np.random.rand(10)

# %%
np.random.rand(10,5)

# %%
np.random.randn(10)     # randn will give negative no also...

# %% [markdown]
# # CONDITIONAL INDEXING

# %%
a = np.random.randint(1,100,(8,8))

# %%
a

# %%
a > 50

# %%
a[a>50]

# %% [markdown]
# #  SLICING IN MULTIDIMENSION  ARRAY

# %%
a = np.random.randint(1,100,(10,10))

# %%
a

# %%
a[1]

# %%
a[1][4]

# %%
a[(1,4)]

# %%
a[1,4]

# %%
a[2:4,:]
a

# %%
a

# %%
a[2][2: :3]

# %%
a[2:9:3,2:9:3]

# %%
a[5:6:1,4:6:1]

# %% [markdown]
# # HANDLIN THE MISSING VALUES
#  - np.isnan     detect missing values
#  - np.nan_to_num()       # not a number
#  - np.isinf      # to dectect the infinte value

# %%
a=np.array([1,2,np.nan,4,np.nan,6])
np.isnan(a)

# %%
       #  np.nan_to_num()

# %%
a=np.array([1,2,np.nan,4,np.nan,6])
ca = np.nan_to_num(a)          # default value is 0
ca

# %%
ca = np.nan_to_num(a,nan=15)
ca

# %%
a = np.array([1,2,np.inf,4,-np.inf,6])
np.isinf(a)

# %%
np.nan_to_num(a,posinf=1000, neginf=-1000)

# %%
np.nan_to_num(a,posinf=1000, neginf=-1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 np.nan_to_num(a,posinf=1000, neginf=-1000)
#
# NameError: name 'a' is not defined

# %%
l1 = [1,2,3,4,5]
a1 = np.array(l1)
a1
# Out:
# array([1, 2, 3, 4, 5])

# %%
a1.shape
# Out:
# (5,)
